# %%
1+1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: 2</div>

# %%
from pyspark.sql.functions import lit,col,concat, substring
NO_OF_ROWS = 100000
dfIds = spark.range(NO_OF_ROWS).withColumn("IDAsString", concat(lit("Str="), col("id")))
display(dfIds)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>IDAsString</th></tr></thead><tbody><tr><td>0</td><td>Str=0</td></tr><tr><td>1</td><td>Str=1</td></tr><tr><td>2</td><td>Str=2</td></tr><tr><td>3</td><td>Str=3</td></tr><tr><td>4</td><td>Str=4</td></tr><tr><td>5</td><td>Str=5</td></tr><tr><td>6</td><td>Str=6</td></tr><tr><td>7</td><td>Str=7</td></tr><tr><td>8</td><td>Str=8</td></tr><tr><td>9</td><td>Str=9</td></tr><tr><td>10</td><td>Str=10</td></tr><tr><td>11</td><td>Str=11</td></tr><tr><td>12</td><td>Str=12</td></tr><tr><td>13</td><td>Str=13</td></tr><tr><td>14</td><td>Str=14</td></tr><tr><td>15</td><td>Str=15</td></tr><tr><td>16</td><td>Str=16</td></tr><tr><td>17</td><td>Str=17</td></tr><tr><td>18</td><td>Str=18</td></tr><tr><td>19</td><td>Str=19</td></tr><tr><td>20</td><td>Str=20</td></tr><tr><td>21</td><td>Str=21</td></tr><tr><td>22</td><td>Str=22</td></tr><tr><td>23</td><td>Str=23</td></tr><tr><td>24</td><td>Str=24</td></tr><tr><td>25</td><td>Str=25</td></tr><tr><td>26</td><td>Str=26</td></tr><tr><td>27</td><td>Str=27</td></tr><tr><td>28</td><td>Str=28</td></tr><tr><td>29</td><td>Str=29</td></tr><tr><td>30</td><td>Str=30</td></tr><tr><td>31</td><td>Str=31</td></tr><tr><td>32</td><td>Str=32</td></tr><tr><td>33</td><td>Str=33</td></tr><tr><td>34</td><td>Str=34</td></tr><tr><td>35</td><td>Str=35</td></tr><tr><td>36</td><td>Str=36</td></tr><tr><td>37</td><td>Str=37</td></tr><tr><td>38</td><td>Str=38</td></tr><tr><td>39</td><td>Str=39</td></tr><tr><td>40</td><td>Str=40</td></tr><tr><td>41</td><td>Str=41</td></tr><tr><td>42</td><td>Str=42</td></tr><tr><td>43</td><td>Str=43</td></tr><tr><td>44</td><td>Str=44</td></tr><tr><td>45</td><td>Str=45</td></tr><tr><td>46</td><td>Str=46</td></tr><tr><td>47</td><td>Str=47</td></tr><tr><td>48</td><td>Str=48</td></tr><tr><td>49</td><td>Str=49</td></tr><tr><td>50</td><td>Str=50</td></tr><tr><td>51</td><td>Str=51</td></tr><tr><td>52</td><td>Str=52</td></tr><tr><td>53</td><td>Str=53</td></tr><tr><td>54</td><td>Str=54</td></tr><tr><td>55</td><td>Str=55</td></tr><tr><td>56</td><td>Str=56</td></tr><tr><td>57</td><td>Str=57</td></tr><tr><td>58</td><td>Str=58</td></tr><tr><td>59</td><td>Str=59</td></tr><tr><td>60</td><td>Str=60</td></tr><tr><td>61</td><td>Str=61</td></tr><tr><td>62</td><td>Str=62</td></tr><tr><td>63</td><td>Str=63</td></tr><tr><td>64</td><td>Str=64</td></tr><tr><td>65</td><td>Str=65</td></tr><tr><td>66</td><td>Str=66</td></tr><tr><td>67</td><td>Str=67</td></tr><tr><td>68</td><td>Str=68</td></tr><tr><td>69</td><td>Str=69</td></tr><tr><td>70</td><td>Str=70</td></tr><tr><td>71</td><td>Str=71</td></tr><tr><td>72</td><td>Str=72</td></tr><tr><td>73</td><td>Str=73</td></tr><tr><td>74</td><td>Str=74</td></tr><tr><td>75</td><td>Str=75</td></tr><tr><td>76</td><td>Str=76</td></tr><tr><td>77</td><td>Str=77</td></tr><tr><td>78</td><td>Str=78</td></tr><tr><td>79</td><td>Str=79</td></tr><tr><td>80</td><td>Str=80</td></tr><tr><td>81</td><td>Str=81</td></tr><tr><td>82</td><td>Str=82</td></tr><tr><td>83</td><td>Str=83</td></tr><tr><td>84</td><td>Str=84</td></tr><tr><td>85</td><td>Str=85</td></tr><tr><td>86</td><td>Str=86</td></tr><tr><td>87</td><td>Str=87</td></tr><tr><td>88</td><td>Str=88</td></tr><tr><td>89</td><td>Str=89</td></tr><tr><td>90</td><td>Str=90</td></tr><tr><td>91</td><td>Str=91</td></tr><tr><td>92</td><td>Str=92</td></tr><tr><td>93</td><td>Str=93</td></tr><tr><td>94</td><td>Str=94</td></tr><tr><td>95</td><td>Str=95</td></tr><tr><td>96</td><td>Str=96</td></tr><tr><td>97</td><td>Str=97</td></tr><tr><td>98</td><td>Str=98</td></tr><tr><td>99</td><td>Str=99</td></tr><tr><td>100</td><td>Str=100</td></tr><tr><td>101</td><td>Str=101</td></tr><tr><td>102</td><td>Str=102</td></tr><tr><td>103</td><td>Str=103</td></tr><tr><td>104</td><td>Str=104</td></tr><tr><td>105</td><td>Str=105</td></tr><tr><td>106</td><td>Str=106</td></tr><tr><td>107</td><td>Str=107</td></tr><tr><td>108</td><td>Str=108</td></tr><tr><td>109</td><td>St ...

# %%
path = "/tmp/parquet/10MIDs"
dfIds.write.mode("Overwrite").parquet(path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfBeforeAppend = spark.read.parquet(path)
print("No Rows before append:", dfBeforeAppend.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">No Rows before append: 100000
# </div>

# %%
# %sql
-- DROP IF EXIST
DROP TABLE IF EXISTS IDS;
-- Skapa en tabell som pekar på PARQUET
CREATE TABLE IDS
    USING parquet
    OPTIONS (
      path "/tmp/parquet/10MIDs"
    )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM IDS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>100000</td></tr></tbody></table></div>

# %%
# Append Rows
NO_APPEEND_NEW_ROWS = 10000
dfAppendRows = spark.range(NO_OF_ROWS + NO_APPEEND_NEW_ROWS).filter("id >= {rows}".format(rows=NO_OF_ROWS)).withColumn("IDAsString", f.concat(f.lit("Str="), f.col("id")))
dfAppendRows.write.mode("Append").parquet(path)
dfAfterAppend = spark.read.parquet(path)
print("NoROws after", dfAfterAppend.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">NoROws after 110000
# </div>

# %%
# %sql
SELECT COUNT(*) FROM IDS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>100000</td></tr></tbody></table></div>

# %%
# %sql
REFRESH TABLE IDS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM IDS
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>110000</td></tr></tbody></table></div>

# %% [markdown]
# # Append data to partitions using parquet

# %%
# Create a col to partition on
# Just take last digit in id as partition id
dfId = spark.read.parquet(path)
dfId3 = dfId.withColumn("PartitionId", f.substring(f.col("id"), -1, 1))
# substring(column, -1, 1)
display(dfId3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>IDAsString</th><th>PartitionId</th></tr></thead><tbody><tr><td>50000</td><td>Str=50000</td><td>0</td></tr><tr><td>50001</td><td>Str=50001</td><td>1</td></tr><tr><td>50002</td><td>Str=50002</td><td>2</td></tr><tr><td>50003</td><td>Str=50003</td><td>3</td></tr><tr><td>50004</td><td>Str=50004</td><td>4</td></tr><tr><td>50005</td><td>Str=50005</td><td>5</td></tr><tr><td>50006</td><td>Str=50006</td><td>6</td></tr><tr><td>50007</td><td>Str=50007</td><td>7</td></tr><tr><td>50008</td><td>Str=50008</td><td>8</td></tr><tr><td>50009</td><td>Str=50009</td><td>9</td></tr><tr><td>50010</td><td>Str=50010</td><td>0</td></tr><tr><td>50011</td><td>Str=50011</td><td>1</td></tr><tr><td>50012</td><td>Str=50012</td><td>2</td></tr><tr><td>50013</td><td>Str=50013</td><td>3</td></tr><tr><td>50014</td><td>Str=50014</td><td>4</td></tr><tr><td>50015</td><td>Str=50015</td><td>5</td></tr><tr><td>50016</td><td>Str=50016</td><td>6</td></tr><tr><td>50017</td><td>Str=50017</td><td>7</td></tr><tr><td>50018</td><td>Str=50018</td><td>8</td></tr><tr><td>50019</td><td>Str=50019</td><td>9</td></tr><tr><td>50020</td><td>Str=50020</td><td>0</td></tr><tr><td>50021</td><td>Str=50021</td><td>1</td></tr><tr><td>50022</td><td>Str=50022</td><td>2</td></tr><tr><td>50023</td><td>Str=50023</td><td>3</td></tr><tr><td>50024</td><td>Str=50024</td><td>4</td></tr><tr><td>50025</td><td>Str=50025</td><td>5</td></tr><tr><td>50026</td><td>Str=50026</td><td>6</td></tr><tr><td>50027</td><td>Str=50027</td><td>7</td></tr><tr><td>50028</td><td>Str=50028</td><td>8</td></tr><tr><td>50029</td><td>Str=50029</td><td>9</td></tr><tr><td>50030</td><td>Str=50030</td><td>0</td></tr><tr><td>50031</td><td>Str=50031</td><td>1</td></tr><tr><td>50032</td><td>Str=50032</td><td>2</td></tr><tr><td>50033</td><td>Str=50033</td><td>3</td></tr><tr><td>50034</td><td>Str=50034</td><td>4</td></tr><tr><td>50035</td><td>Str=50035</td><td>5</td></tr><tr><td>50036</td><td>Str=50036</td><td>6</td></tr><tr><td>50037</td><td>Str=50037</td><td>7</td></tr><tr><td>50038</td><td>Str=50038</td><td>8</td></tr><tr><td>50039</td><td>Str=50039</td><td>9</td></tr><tr><td>50040</td><td>Str=50040</td><td>0</td></tr><tr><td>50041</td><td>Str=50041</td><td>1</td></tr><tr><td>50042</td><td>Str=50042</td><td>2</td></tr><tr><td>50043</td><td>Str=50043</td><td>3</td></tr><tr><td>50044</td><td>Str=50044</td><td>4</td></tr><tr><td>50045</td><td>Str=50045</td><td>5</td></tr><tr><td>50046</td><td>Str=50046</td><td>6</td></tr><tr><td>50047</td><td>Str=50047</td><td>7</td></tr><tr><td>50048</td><td>Str=50048</td><td>8</td></tr><tr><td>50049</td><td>Str=50049</td><td>9</td></tr><tr><td>50050</td><td>Str=50050</td><td>0</td></tr><tr><td>50051</td><td>Str=50051</td><td>1</td></tr><tr><td>50052</td><td>Str=50052</td><td>2</td></tr><tr><td>50053</td><td>Str=50053</td><td>3</td></tr><tr><td>50054</td><td>Str=50054</td><td>4</td></tr><tr><td>50055</td><td>Str=50055</td><td>5</td></tr><tr><td>50056</td><td>Str=50056</td><td>6</td></tr><tr><td>50057</td><td>Str=50057</td><td>7</td></tr><tr><td>50058</td><td>Str=50058</td><td>8</td></tr><tr><td>50059</td><td>Str=50059</td><td>9</td></tr><tr><td>50060</td><td>Str=50060</td><td>0</td></tr><tr><td>50061</td><td>Str=50061</td><td>1</td></tr><tr><td>50062</td><td>Str=50062</td><td>2</td></tr><tr><td>50063</td><td>Str=50063</td><td>3</td></tr><tr><td>50064</td><td>Str=50064</td><td>4</td></tr><tr><td>50065</td><td>Str=50065</td><td>5</td></tr><tr><td>50066</td><td>Str=50066</td><td>6</td></tr><tr><td>50067</td><td>Str=50067</td><td>7</td></tr><tr><td>50068</td><td>Str=50068</td><td>8</td></tr><tr><td>50069</td><td>Str=50069</td><td>9</td></tr><tr><td>50070</td><td>Str=50070</td><td>0</td></tr><tr><td>50071</td><td>Str=50071</td><td>1</td></tr><tr><td>50072</td><td>Str=50072</td><td>2</td></tr><tr><td>50073</td><td>Str=50073</td><td>3</td></tr><tr><td>50074</td><td>Str=50074</td><td>4 ...

# %%
# Write IDS partitioned on last digit
pathPar = "/tmp/parquet/IDSPartitioned/"
dfId3.write.partitionBy("PartitionId").mode("Overwrite").parquet(pathPar)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DROP TABLE IF EXISTS IDPARTITIONED;
-- Create table on top of partitioned data
CREATE TABLE IDPARTITIONED (id long, IDAsString string, PartitionId int)
    USING parquet
    OPTIONS (
      path "/tmp/parquet/IDSPartitioned/"
    )
    partitioned by (PartitionId)
    -- When the table schema is not provided, schema and partition columns will be inferred
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
MSCK REPAIR TABLE IDPARTITIONED
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select count(*), PartitionId from IDPARTITIONED group by PartitionId order by PartitionId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th><th>PartitionId</th></tr></thead><tbody><tr><td>11000</td><td>0</td></tr><tr><td>11000</td><td>1</td></tr><tr><td>11000</td><td>2</td></tr><tr><td>11000</td><td>3</td></tr><tr><td>11000</td><td>4</td></tr><tr><td>11000</td><td>5</td></tr><tr><td>11000</td><td>6</td></tr><tr><td>11000</td><td>7</td></tr><tr><td>11000</td><td>8</td></tr><tr><td>11000</td><td>9</td></tr></tbody></table></div>

# %%
# %fs
ls /mnt/datasetsneugen2/parquet/IDSPartitioned/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/*/</td><td>*/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=0/</td><td>PartitionId=0/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=1/</td><td>PartitionId=1/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=2/</td><td>PartitionId=2/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=3/</td><td>PartitionId=3/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=4/</td><td>PartitionId=4/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=5/</td><td>PartitionId=5/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=6/</td><td>PartitionId=6/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=7/</td><td>PartitionId=7/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=8/</td><td>PartitionId=8/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/PartitionId=9/</td><td>PartitionId=9/</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/mnt/datasetsneugen2/parquet/IDSPartitioned/_committed_4328684544942137249</td><td>_committed_4328684544942137249</td><td>35</td></tr></tbody></table></div>

# %%
dfReadPar = spark.read.parquet(pathPar)
display(dfReadPar.groupBy("PartitionId").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PartitionId</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>11000</td></tr><tr><td>3</td><td>11000</td></tr><tr><td>5</td><td>11000</td></tr><tr><td>4</td><td>11000</td></tr><tr><td>2</td><td>11000</td></tr><tr><td>0</td><td>11000</td></tr><tr><td>9</td><td>11000</td></tr><tr><td>6</td><td>11000</td></tr><tr><td>8</td><td>11000</td></tr><tr><td>7</td><td>11000</td></tr></tbody></table></div>

# %%
# filter out ids with partition 0 and 1 and append to original parquet
dfFilter01 = dfId3.filter("PartitionId == 0 or PartitionId == 1")
# append these rows to original parquet
dfFilter01.write.partitionBy("PartitionId").mode("Append").parquet(pathPar)
# Test result
dfReadPar = spark.read.parquet(pathPar)
display(dfReadPar.groupBy("PartitionId").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PartitionId</th><th>count</th></tr></thead><tbody><tr><td>6</td><td>11000</td></tr><tr><td>5</td><td>11000</td></tr><tr><td>9</td><td>11000</td></tr><tr><td>4</td><td>11000</td></tr><tr><td>8</td><td>11000</td></tr><tr><td>7</td><td>11000</td></tr><tr><td>2</td><td>11000</td></tr><tr><td>1</td><td>22000</td></tr><tr><td>3</td><td>11000</td></tr><tr><td>0</td><td>22000</td></tr></tbody></table></div>

# %%
# %sql
-- check table
select count(*), PartitionId from IDPARTITIONED group by PartitionId order by PartitionId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th><th>PartitionId</th></tr></thead><tbody><tr><td>11000</td><td>0</td></tr><tr><td>11000</td><td>1</td></tr><tr><td>11000</td><td>2</td></tr><tr><td>11000</td><td>3</td></tr><tr><td>11000</td><td>4</td></tr><tr><td>11000</td><td>5</td></tr><tr><td>11000</td><td>6</td></tr><tr><td>11000</td><td>7</td></tr><tr><td>11000</td><td>8</td></tr><tr><td>11000</td><td>9</td></tr></tbody></table></div>

# %%
# %sql
MSCK REPAIR TABLE IDPARTITIONED;
select count(*), PartitionId from IDPARTITIONED group by PartitionId order by PartitionId
-- We should now be able to see the changes
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th><th>PartitionId</th></tr></thead><tbody><tr><td>22000</td><td>0</td></tr><tr><td>22000</td><td>1</td></tr><tr><td>11000</td><td>2</td></tr><tr><td>11000</td><td>3</td></tr><tr><td>11000</td><td>4</td></tr><tr><td>11000</td><td>5</td></tr><tr><td>11000</td><td>6</td></tr><tr><td>11000</td><td>7</td></tr><tr><td>11000</td><td>8</td></tr><tr><td>11000</td><td>9</td></tr></tbody></table></div>

# %% [markdown]
# #What if we tried to update specific rows?
# Parquet does not allow updates. That means we would have some options:
# - Rewritee all data
# - Read exisitng data and create a new updated version of the data and rewrite all data
# - FIgure out in what partition we want to change and do the above for only the partition
#
# We have our data partitioned on the Partition ID.

# %%
# %sql
select * from IDPARTITIONED where id < 30
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>IDAsString</th><th>PartitionId</th></tr></thead><tbody><tr><td>3</td><td>Str=3</td><td>3</td></tr><tr><td>13</td><td>Str=13</td><td>3</td></tr><tr><td>23</td><td>Str=23</td><td>3</td></tr><tr><td>9</td><td>Str=9</td><td>9</td></tr><tr><td>19</td><td>Str=19</td><td>9</td></tr><tr><td>29</td><td>Str=29</td><td>9</td></tr><tr><td>2</td><td>Str=2</td><td>2</td></tr><tr><td>12</td><td>Str=12</td><td>2</td></tr><tr><td>22</td><td>Str=22</td><td>2</td></tr><tr><td>6</td><td>Str=6</td><td>6</td></tr><tr><td>16</td><td>Str=16</td><td>6</td></tr><tr><td>26</td><td>Str=26</td><td>6</td></tr><tr><td>7</td><td>Str=7</td><td>7</td></tr><tr><td>17</td><td>Str=17</td><td>7</td></tr><tr><td>27</td><td>Str=27</td><td>7</td></tr><tr><td>8</td><td>Str=8</td><td>8</td></tr><tr><td>18</td><td>Str=18</td><td>8</td></tr><tr><td>28</td><td>Str=28</td><td>8</td></tr><tr><td>4</td><td>Str=4</td><td>4</td></tr><tr><td>14</td><td>Str=14</td><td>4</td></tr><tr><td>24</td><td>Str=24</td><td>4</td></tr><tr><td>1</td><td>Str=1</td><td>1</td></tr><tr><td>11</td><td>Str=11</td><td>1</td></tr><tr><td>21</td><td>Str=21</td><td>1</td></tr><tr><td>1</td><td>Str=1</td><td>1</td></tr><tr><td>11</td><td>Str=11</td><td>1</td></tr><tr><td>21</td><td>Str=21</td><td>1</td></tr><tr><td>5</td><td>Str=5</td><td>5</td></tr><tr><td>15</td><td>Str=15</td><td>5</td></tr><tr><td>25</td><td>Str=25</td><td>5</td></tr><tr><td>0</td><td>Str=0</td><td>0</td></tr><tr><td>10</td><td>Str=10</td><td>0</td></tr><tr><td>20</td><td>Str=20</td><td>0</td></tr><tr><td>0</td><td>Str=0</td><td>0</td></tr><tr><td>10</td><td>Str=10</td><td>0</td></tr><tr><td>20</td><td>Str=20</td><td>0</td></tr></tbody></table></div>

# %%
# What if we would like to update the row where id = 50013 or id = 50033 and we want to add a string fixed to the IDAsString
# Both are in partition 3 so we can read the partion 3 only and write the update back

dfPartition = spark.sql("select * from IDPARTITIONED where PartitionId = 3")
dfPartition.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+-----------+
#    id|IDAsString|PartitionId|
# +-----+----------+-----------+
# 50003| Str=50003|          3|
# 50013| Str=50013|          3|
# 50023| Str=50023|          3|
# 50033| Str=50033|          3|
# 50043| Str=50043|          3|
# +-----+----------+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Some logic for update
dfChange = dfPartition.filter("id = 50013 or id = 50033")
dfChange.show()

dfFixed = dfChange.withColumn("IDAsString", f.concat(f.col("IDAsString"), f.lit("_fixed")))
dfFixed.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----------+-----------+
#    id|IDAsString|PartitionId|
# +-----+----------+-----------+
# 50013| Str=50013|          3|
# 50033| Str=50033|          3|
# +-----+----------+-----------+
#
# +-----+---------------+-----------+
#    id|     IDAsString|PartitionId|
# +-----+---------------+-----------+
# 50013|Str=50013_fixed|          3|
# 50033|Str=50033_fixed|          3|
# +-----+---------------+-----------+
#
# </div>

# %%
# Take original data and put chnages in and write back
# Here dropping rows that should be updated and then adding by union. (Remember there is no update - a DF is immuatble)
# Get a new DF with the rows that should be updated
dfFiltered = dfPartition.filter("id != 50033 and id != 50013")
# Add the updated rows to a new DF
dfUpdatedDF = dfFiltered.union(dfFixed)
display(dfUpdatedDF.filter("id > 50012").orderBy("id"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>IDAsString</th><th>PartitionId</th></tr></thead><tbody><tr><td>50013</td><td>Str=50013_fixed</td><td>3</td></tr><tr><td>50023</td><td>Str=50023</td><td>3</td></tr><tr><td>50033</td><td>Str=50033_fixed</td><td>3</td></tr><tr><td>50043</td><td>Str=50043</td><td>3</td></tr><tr><td>50053</td><td>Str=50053</td><td>3</td></tr><tr><td>50063</td><td>Str=50063</td><td>3</td></tr><tr><td>50073</td><td>Str=50073</td><td>3</td></tr><tr><td>50083</td><td>Str=50083</td><td>3</td></tr><tr><td>50093</td><td>Str=50093</td><td>3</td></tr><tr><td>50103</td><td>Str=50103</td><td>3</td></tr><tr><td>50113</td><td>Str=50113</td><td>3</td></tr><tr><td>50123</td><td>Str=50123</td><td>3</td></tr><tr><td>50133</td><td>Str=50133</td><td>3</td></tr><tr><td>50143</td><td>Str=50143</td><td>3</td></tr><tr><td>50153</td><td>Str=50153</td><td>3</td></tr><tr><td>50163</td><td>Str=50163</td><td>3</td></tr><tr><td>50173</td><td>Str=50173</td><td>3</td></tr><tr><td>50183</td><td>Str=50183</td><td>3</td></tr><tr><td>50193</td><td>Str=50193</td><td>3</td></tr><tr><td>50203</td><td>Str=50203</td><td>3</td></tr><tr><td>50213</td><td>Str=50213</td><td>3</td></tr><tr><td>50223</td><td>Str=50223</td><td>3</td></tr><tr><td>50233</td><td>Str=50233</td><td>3</td></tr><tr><td>50243</td><td>Str=50243</td><td>3</td></tr><tr><td>50253</td><td>Str=50253</td><td>3</td></tr><tr><td>50263</td><td>Str=50263</td><td>3</td></tr><tr><td>50273</td><td>Str=50273</td><td>3</td></tr><tr><td>50283</td><td>Str=50283</td><td>3</td></tr><tr><td>50293</td><td>Str=50293</td><td>3</td></tr><tr><td>50303</td><td>Str=50303</td><td>3</td></tr><tr><td>50313</td><td>Str=50313</td><td>3</td></tr><tr><td>50323</td><td>Str=50323</td><td>3</td></tr><tr><td>50333</td><td>Str=50333</td><td>3</td></tr><tr><td>50343</td><td>Str=50343</td><td>3</td></tr><tr><td>50353</td><td>Str=50353</td><td>3</td></tr><tr><td>50363</td><td>Str=50363</td><td>3</td></tr><tr><td>50373</td><td>Str=50373</td><td>3</td></tr><tr><td>50383</td><td>Str=50383</td><td>3</td></tr><tr><td>50393</td><td>Str=50393</td><td>3</td></tr><tr><td>50403</td><td>Str=50403</td><td>3</td></tr><tr><td>50413</td><td>Str=50413</td><td>3</td></tr><tr><td>50423</td><td>Str=50423</td><td>3</td></tr><tr><td>50433</td><td>Str=50433</td><td>3</td></tr><tr><td>50443</td><td>Str=50443</td><td>3</td></tr><tr><td>50453</td><td>Str=50453</td><td>3</td></tr><tr><td>50463</td><td>Str=50463</td><td>3</td></tr><tr><td>50473</td><td>Str=50473</td><td>3</td></tr><tr><td>50483</td><td>Str=50483</td><td>3</td></tr><tr><td>50493</td><td>Str=50493</td><td>3</td></tr><tr><td>50503</td><td>Str=50503</td><td>3</td></tr><tr><td>50513</td><td>Str=50513</td><td>3</td></tr><tr><td>50523</td><td>Str=50523</td><td>3</td></tr><tr><td>50533</td><td>Str=50533</td><td>3</td></tr><tr><td>50543</td><td>Str=50543</td><td>3</td></tr><tr><td>50553</td><td>Str=50553</td><td>3</td></tr><tr><td>50563</td><td>Str=50563</td><td>3</td></tr><tr><td>50573</td><td>Str=50573</td><td>3</td></tr><tr><td>50583</td><td>Str=50583</td><td>3</td></tr><tr><td>50593</td><td>Str=50593</td><td>3</td></tr><tr><td>50603</td><td>Str=50603</td><td>3</td></tr><tr><td>50613</td><td>Str=50613</td><td>3</td></tr><tr><td>50623</td><td>Str=50623</td><td>3</td></tr><tr><td>50633</td><td>Str=50633</td><td>3</td></tr><tr><td>50643</td><td>Str=50643</td><td>3</td></tr><tr><td>50653</td><td>Str=50653</td><td>3</td></tr><tr><td>50663</td><td>Str=50663</td><td>3</td></tr><tr><td>50673</td><td>Str=50673</td><td>3</td></tr><tr><td>50683</td><td>Str=50683</td><td>3</td></tr><tr><td>50693</td><td>Str=50693</td><td>3</td></tr><tr><td>50703</td><td>Str=50703</td><td>3</td></tr><tr><td>50713</td><td>Str=50713</td><td>3</td></tr><tr><td>50723</td><td>Str=50723</td><td>3</td></tr><tr><td>50733</td><td>Str=50733</td><td>3</td></tr><tr><td>50743</td><td>Str=50743</td><td>3</td></tr><tr><td>50753</td><td>Str=507 ...

# %%
# Overwrite the correct parition with our new DF containing all data fro partion 3
dfUpdatedDF.write.mode("overwrite").parquet(pathPar + "PartitionId={partion_name}/".format(partion_name="3"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# The rows in partitio 3 are updated in our final table.
display(spark.read.parquet(pathPar).filter("id < 50015 and id > 50011 or id < 50034 and id > 50032").orderBy("id"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>IDAsString</th><th>PartitionId</th></tr></thead><tbody><tr><td>50012</td><td>Str=50012</td><td>2</td></tr><tr><td>50013</td><td>Str=50013_fixed</td><td>3</td></tr><tr><td>50014</td><td>Str=50014</td><td>4</td></tr><tr><td>50033</td><td>Str=50033_fixed</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# #### Note - It´s easier to append data as you can write append to a specific partition as we showed above. The updates are harder as you are forces to rewrite at least the full partition.

# %% [markdown]
# #### Note 2 - DELTA - By using the delta file format you can do upserts into different partitions much easier and not risking ovwerwriting your data by using time travel and ACID transactions.
# Also table meta-data will be updated and in sync when using delta.
